# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Anne Valvezan"
reason = "I am an engineer that worked in ML and software development but wanted to improve my practical knowledge in Science."
fun_fact = "I enjoy spending my free time in artistic activities like drawing and taking photos."

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Anne Valvezan. I’m excited to learn because I am an engineer that worked in ML and software development but wanted to improve my practical knowledge in Science.. A fun fact about me is: I enjoy spending my free time in artistic activities like drawing and taking photos..
